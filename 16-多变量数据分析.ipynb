# %%
import mytools
import pandas as pd

# %%
数据表 = mytools.读取SPSS数据文件(R'data\国家认同数据清理后.sav')

# %%
# 创建年级、政治面貌和会打多少分的交互表
cross_tab = pd.crosstab(index=[数据表['年级'], 数据表['发展信心']], 
columns=数据表['政治面貌'], 
margins=True, normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 政治面貌             团员        党员        群众        其他       All
# 年级  发展信心
# 预科  不清楚    0.006427  0.000000  0.000000  0.000000  0.006427
#     没信心    0.001285  0.000000  0.000000  0.000000  0.001285
#     担忧不好说  0.001285  0.000000  0.000000  0.000000  0.001285
#     很有信心   0.006427  0.000000  0.001285  0.000000  0.007712
# 大一  不清楚    0.019280  0.001285  0.002571  0.000000  0.023136
#     没信心    0.006427  0.000000  0.000000  0.001285  0.007712
#     担忧不好说  0.080977  0.006427  0.012853  0.001285  0.101542
#     很有信心   0.185090  0.007712  0.017995  0.001285  0.212082
# 大二  不清楚    0.011568  0.000000  0.003856  0.000000  0.015424
#     没信心    0.010283  0.008997  0.002571  0.000000  0.021851
#     担忧不好说  0.086118  0.008997  0.014139  0.001285  0.110540
#     很有信心   0.137532  0.016710  0.012853  0.005141  0.172237
# 大三  不清楚    0.011568  0.005141  0.001285  0.000000  0.017995
#     没信心    0.006427  0.000000  0.006427  0.000000  0.012853
#     担忧不好说  0.034704  0.016710  0.014139  0.005141  0.070694
#     很有信心   0.057841  0.034704  0.006427  0.005141  0.104113
# 大四  不清楚    0.001285  0.001285  0.002571  0.000000  0.005141
#     没信心    0.001285  0.000000  0.000000  0.000000  0.001285
#     担忧不好说  0.024422  0.008997  0.006427  0.000000  0.039846
#     很有信心   0.046272  0.015424  0.005141  0.000000  0.066838
# All        0.736504  0.132391  0.110540  0.020566  1.000000

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = "大一"

# 筛选出特定年级的数据
df_specific_grade = 数据表[数据表['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['世博会'], df_specific_grade['中国传统文化'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 12.329714939543887 0.05500474643288003
# 中国传统文化  古板，跟不上潮流  比较肯定  富有内涵，意义深刻
# 世博会
# 没感觉            0     2          5
# 一般             2    13         18
# 比较好            3    17         41
# 感到自豪           1    36        130

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'世博会','中国传统文化')
# Out:
# tau_y系数: 0.0253 极弱相关或无相关
# --------  -  --  ---
# 没感觉    0   2    5
# 一般      2  13   18
# 比较好    3  17   41
# 感到自豪  1  36  130
# --------  -  --  ---
# 卡方值： 12.33, p值： 0.0550,自由度:6。
# 接受虚无假设

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = "大二"

# 筛选出特定年级的数据
df_specific_grade = 数据表[数据表['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['会隐瞒身份吗'], df_specific_grade['会打多少分'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 60.37260745378882 4.5288140685760183e-07
# 会打多少分    零到二十  20~40  四十到六十  六十到八十  八十到一百
# 会隐瞒身份吗
# 绝对不会        2      5     14     66     56
# 很可能不会       1      2      8      8      2
# 也许会也许不会     4      4     20     10      5
# 可能会         3      1     14     18      4
# 一定会         0      0      1      1      0

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'会隐瞒身份吗','会打多少分')
# Out:
# tau_y系数: 0.0770 极弱相关或无相关
# --------------  -  -  --  --  --
# 绝对不会        2  5  14  66  56
# 很可能不会      1  2   8   8   2
# 也许会也许不会  4  4  20  10   5
# 可能会          3  1  14  18   4
# 一定会          0  0   1   1   0
# --------------  -  -  --  --  --
# 卡方值： 60.37, p值： 0.0000,自由度:16。
# 拒绝虚无假设

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = "大三"

# 筛选出特定年级的数据
df_specific_grade = 数据表[数据表['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['发展信心'], df_specific_grade['国歌升起'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 41.1335694235481 4.72957203158891e-06
# 国歌升起   没感觉  一般  比较激动  感到非常激动
# 发展信心
# 不清楚      2   7     5       0
# 没信心      0   6     4       0
# 担忧不好说    5  17    28       5
# 很有信心     7   9    30      35

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'发展信心','国歌升起')
# Out:
# tau_y系数: 0.0921 极弱相关或无相关
# ----------  -  --  --  --
# 不清楚      2   7   5   0
# 没信心      0   6   4   0
# 担忧不好说  5  17  28   5
# 很有信心    7   9  30  35
# ----------  -  --  --  --
# 卡方值： 41.13, p值： 0.0000,自由度:9。
# 拒绝虚无假设

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = "大四"

# 筛选出特定年级的数据
df_specific_grade = 数据表[数据表['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['会以中国人自豪吗'], df_specific_grade['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 9.47751673870667 0.3036264221378934
# 政治面貌      团员  党员  群众
# 会以中国人自豪吗
# 不会         2   0   0
# 不太会        3   3   0
# 无所谓        8   1   3
# 有些        12   8   3
# 会         32   8   5

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'会以中国人自豪吗','政治面貌')
# Out:
# tau_y系数: 0.0552 极弱相关或无相关
# ------  --  -  -
# 不会     2  0  0
# 不太会   3  3  0
# 无所谓   8  1  3
# 有些    12  8  3
# 会      32  8  5
# ------  --  -  -
# 卡方值： 9.48, p值： 0.3036,自由度:8。
# 接受虚无假设
